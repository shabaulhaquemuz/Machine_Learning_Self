# %%
# One-Hot Encoding is a method to convert categorical (nominal) data into a binary matrix (0s and 1s), where:
# Each category gets its own column (feature).
# 1 is placed in the column corresponding to that category, and 0s everywhere else.

# Example:
# Suppose you have a column Color:
# Color:
# Red
# Blue
# Green
# Red

# After One-Hot Encoding:
# | Red | Blue | Green |
# | --- | ---- | ----- |
# | 1   | 0    | 0     |
# | 0   | 1    | 0     |
# | 0   | 0    | 1     |
# | 1   | 0    | 0     |

# %%
# 👉 One-Hot Encoding creates extra redundant columns (dummy variable trap).
# 👉 We use drop='first' to remove one column and avoid multicollinearity.
#Multicollinearity means two or more independent variables (features) in a dataset are highly correlated, i.e., they give duplicate information.
#if there are n columns, 1 column is dropped and n-1 column is finally remained

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("cars.csv")

# %%
df.head(5)
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df=df.iloc[:,2:]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,:2],df.iloc[:,2:],test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (6502, 2)

# %%
x_test.shape
# Out:
# (1626, 2)

# %%
from sklearn.preprocessing import OneHotEncoder
pd.get_dummies(df,columns=["fuel","owner"])
# Out:
#       selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0            450000     False         True     False        False
# 1            370000     False         True     False        False
# 2            158000     False        False     False         True
# 3            225000     False         True     False        False
# 4            130000     False        False     False         True
# ...             ...       ...          ...       ...          ...
# 8123         320000     False        False     False         True
# 8124         135000     False         True     False        False
# 8125         382000     False         True     False        False
# 8126         290000     False         True     False        False
# 8127         290000     False         True     False        False
#
#       owner_First Owner  owner_Fourth & Above Owner  owner_Second Owner  \
# 0                  True                       False               False
# 1                 False                       False                True
# 2                 False                       False               False
# 3                  True                       False               False
# 4                  True                       False               False
# ...                 ...                         ...                 ...
# 8123               True                       False               False
# 8124              False                        True               False
# 8125               True                       False               False
# 8126               True                       False               False
# 8127               True                       False               False
#
#       owner_Test Drive Car  owner_Third Owner
# 0                    False              False
# 1                    False              False
# 2                    False               True
# 3                    False              False
# 4                    False              False
# ...                    ...                ...
# 8123                 False              False
# 8124                 False              False
# 8125                 False              False
# 8126                 False              False
# 8127                 False              False
#
# [8128 rows x 10 columns]

# %%
pd.get_dummies(df,columns=["fuel","owner"],drop_first=True,dtype=np.int32)
# Out:
#       selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0            450000            1         0            0
# 1            370000            1         0            0
# 2            158000            0         0            1
# 3            225000            1         0            0
# 4            130000            0         0            1
# ...             ...          ...       ...          ...
# 8123         320000            0         0            1
# 8124         135000            1         0            0
# 8125         382000            1         0            0
# 8126         290000            1         0            0
# 8127         290000            1         0            0
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                              0                   0                     0
# 1                              0                   1                     0
# 2                              0                   0                     0
# 3                              0                   0                     0
# 4                              0                   0                     0
# ...                          ...                 ...                   ...
# 8123                           0                   0                     0
# 8124                           1                   0                     0
# 8125                           0                   0                     0
# 8126                           0                   0                     0
# 8127                           0                   0                     0
#
#       owner_Third Owner
# 0                     0
# 1                     0
# 2                     1
# 3                     0
# 4                     0
# ...                 ...
# 8123                  0
# 8124                  0
# 8125                  0
# 8126                  0
# 8127                  0
#
# [8128 rows x 8 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
df1=pd.read_csv("cars.csv")

# %%
df1.head(5)
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df1=df1.iloc[:,2:]

# %%
df1.head(5)
# Out:
#      fuel         owner  selling_price
# 0  Diesel   First Owner         450000
# 1  Diesel  Second Owner         370000
# 2  Petrol   Third Owner         158000
# 3  Diesel   First Owner         225000
# 4  Petrol   First Owner         130000

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df1.iloc[:,:2],df1.iloc[:,2:],test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (6502, 2)

# %%
x_test.shape
# Out:
# (1626, 2)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(drop="first",sparse_output=False,dtype=np.int32)
ohe_encoded=ohe.fit_transform(df1[["fuel","owner"]])
ohe_encoded_df=pd.DataFrame(ohe_encoded,columns=ohe.get_feature_names_out(["fuel","owner"]))

# %%
ohe_encoded_df
# Out:
#       fuel_Diesel  fuel_LPG  fuel_Petrol  owner_Fourth & Above Owner  \
# 0               1         0            0                           0
# 1               1         0            0                           0
# 2               0         0            1                           0
# 3               1         0            0                           0
# 4               0         0            1                           0
# ...           ...       ...          ...                         ...
# 8123            0         0            1                           0
# 8124            1         0            0                           1
# 8125            1         0            0                           0
# 8126            1         0            0                           0
# 8127            1         0            0                           0
#
#       owner_Second Owner  owner_Test Drive Car  owner_Third Owner
# 0                      0                     0                  0
# 1                      1                     0                  0
# 2                      0                     0                  1
# 3                      0                     0                  0
# 4                      0                     0                  0
# ...                  ...                   ...                ...
# 8123                   0                     0                  0
# 8124                   0                     0                  0
# 8125                   0                     0                  0
# 8126                   0                     0                  0
# 8127                   0                     0                  0
#
# [8128 rows x 7 columns]
